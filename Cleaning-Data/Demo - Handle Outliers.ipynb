# %%
import pandas as pd

df = pd.read_csv('outliers_data.csv')
df.head()
# Out:
#    Student ID  Age
# 0          49   17
# 1         268   15
# 2         120   14
# 3         478   13
# 4         199   17

# %%
df.describe()
# Out:
#        Student ID         Age
# count  527.000000  527.000000
# mean   263.000000   16.007590
# std    152.276065    9.156432
# min      0.000000    3.000000
# 25%    131.500000   13.000000
# 50%    263.000000   14.000000
# 75%    394.500000   16.000000
# max    526.000000   75.000000

# %%
df.Age.sort_values()
# Out:
# 524     3
# 340     4
# 124     4
# 164     6
# 245    10
#        ..
# 153    64
# 152    69
# 162    71
# 389    71
# 360    75
# Name: Age, Length: 527, dtype: int64

# %% [markdown]
# ## Identifying outliers when we know the range

# %%
df.loc[(df['Age'] < 11)]
# Out:
#      Student ID  Age
# 124         449    4
# 164         269    6
# 245         322   10
# 340         435    4
# 524          12    3

# %%
df.loc[(df['Age'] > 18)]
# Out:
#      Student ID  Age
# 8           385   52
# 99          171   63
# 108         259   38
# 117          44   48
# 152         414   69
# 153         427   64
# 162         128   71
# 189           4   60
# 197         221   52
# 210         353   40
# 232         347   53
# 277         416   41
# 318         340   51
# 360         461   75
# 366         231   32
# 383         501   42
# 388         123   54
# 389         144   71
# 411         176   32
# 420         490   55
# 444         141   59
# 445         337   57
# 504         321   62
# 510          78   50
# 517         247   63
# 523           7   28

# %% [markdown]
# ## Identify outliers using standard deviation

# %%
summaries = df.describe().loc[['mean', 'std']]
summaries
# Out:
#       Student ID        Age
# mean  263.000000  16.007590
# std   152.276065   9.156432

# %%
upper_bound = summaries['Age']['mean'] + summaries['Age']['std'] 
lower_bound = summaries['Age']['mean'] - summaries['Age']['std']

# %%
upper_bound
# Out:
# 25.1640221051006

# %%
lower_bound
# Out:
# 6.85115816055405

# %%
violating_rows = df[(df['Age'] < lower_bound) | (df['Age'] > upper_bound)]
violating_rows
# Out:
#      Student ID  Age
# 8           385   52
# 99          171   63
# 108         259   38
# 117          44   48
# 124         449    4
# 152         414   69
# 153         427   64
# 162         128   71
# 164         269    6
# 189           4   60
# 197         221   52
# 210         353   40
# 232         347   53
# 277         416   41
# 318         340   51
# 340         435    4
# 360         461   75
# 366         231   32
# 383         501   42
# 388         123   54
# 389         144   71
# 411         176   32
# 420         490   55
# 444         141   59
# 445         337   57
# 504         321   62
# 510          78   50
# 517         247   63
# 523           7   28
# 524          12    3

# %% [markdown]
# ## Remove outliers entirely from the dataset

# %%
outliers_index = violating_rows.index
outliers_index
# Out:
# Int64Index([  8,  99, 108, 117, 124, 152, 153, 162, 164, 189, 197, 210, 232,
#             277, 318, 340, 360, 366, 383, 388, 389, 411, 420, 444, 445, 504,
#             510, 517, 523, 524],
#            dtype='int64')

# %%
newdf = df.drop(index=outliers_index)
newdf.describe()
# Out:
#        Student ID         Age
# count  497.000000  497.000000
# mean   262.917505   14.158954
# std    152.291698    1.939843
# min      0.000000   10.000000
# 25%    131.000000   12.000000
# 50%    263.000000   14.000000
# 75%    394.000000   16.000000
# max    526.000000   17.000000

# %%
df.describe()
# Out:
#        Student ID         Age
# count  527.000000  527.000000
# mean   263.000000   16.007590
# std    152.276065    9.156432
# min      0.000000    3.000000
# 25%    131.500000   13.000000
# 50%    263.000000   14.000000
# 75%    394.500000   16.000000
# max    526.000000   75.000000

# %% [markdown]
# ## Drop method with `inplace = True`

# %%
df.drop(index=outliers_index, inplace=True)
df
# Out:
#      Student ID  Age
# 0            49   17
# 1           268   15
# 2           120   14
# 3           478   13
# 4           199   17
# ..          ...  ...
# 520         139   17
# 521         215   13
# 522         488   15
# 525         235   11
# 526          19   16
#
# [497 rows x 2 columns]

# %%
df.describe()
# Out:
#        Student ID         Age
# count  497.000000  497.000000
# mean   262.917505   14.158954
# std    152.291698    1.939843
# min      0.000000   10.000000
# 25%    131.000000   12.000000
# 50%    263.000000   14.000000
# 75%    394.000000   16.000000
# max    526.000000   17.000000
