# %% [markdown]
# # Exercise - Gathering Multiple Datasets
#
# In this excersise, you will gather the hospital building data using three different gathering methods. The data includes information on hospital buildings such as height, number of stories, etc.
#
# Ensure you programmatically load your dataset(s) into the notebook.

# %%
#Imports - can be modified
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %% [markdown]
# ## 1. Extract a dataset via API

# %% [markdown]
# ### 1.1 Extract a dataset via API
# You may use the requests library to do so programmatically, or manually access the dataset via an API:
#
# https://data.chhs.ca.gov/api/3/action/datastore_search?resource_id=d97adf28-ebaf-4204-a29e-bb6bdb7f96b9

# %%
#FILL IN
#Extract data via API
data_api = requests.get('https://data.chhs.ca.gov/api/3/action/datastore_search?resource_id=d97adf28-ebaf-4204-a29e-bb6bdb7f96b9')
#Raise an exception if we made a request resulting in an error
data_api.raise_for_status()
#Get the JSON
data_api_json = data_api.json()
data_api_json
# Out:
# {'help': 'https://data.chhs.ca.gov/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'limit': 100,
#   'records_format': 'objects',
#   'resource_id': 'd97adf28-ebaf-4204-a29e-bb6bdb7f96b9',
#   'total_estimation_threshold': None,
#   'records': [{'_id': 1,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11210',
#     'Facility Name': 'Alameda Hospital',
#     'City': 'Alameda',
#     'Building Nbr': 'BLD-01278',
#     'Building Name': 'Original Hospital',
#     'Building Status': 'No Gen Acute Care - OSHPD Bldg',
#     'SPC Rating *': 'N/A',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=26HIS&capID2=00000&capID3=00002&agencyCode=OSHPD',
#     'Height (ft)': '44.17',
#     'Stories': '4',
#     'Building Code': 'Unknown',
#     'Building Code Year': None,
#     'Year Completed': '1926',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7626572',
#     'Longitude': '-122.2538986',
#     'Count': '1'},
#    {'_id': 2,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11210',
#     'Facility Name': 'Alameda Hospital',
#     'City': 'Alameda',
#     'Building Nbr': 'BLD-01279',
#     'Building Name': 'Stephens Wing',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=56HIS&capID2=00000&capID3=00012&agencyCode=OSHPD',
#     'Height (ft)': '35',
#     'Stories': '3',
#     'Building Code': '1952 Uniform Building Code (UBC)',
#     'Building Code Year': '1952',
#     'Year Completed': '1956',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.7626572',
#     'Longitude': '-122.2538986',
#     'Count': '1'},
#    {'_id': 3,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11210',
#     'Facility Name': 'Alameda Hospital',
#     'City': 'Alameda',
#     'Building Nbr': 'BLD-01280',
#     'Building Name': 'West Wing',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=68HIS&capID2=00000&capID3=00036&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '2',
#     'Building Code': '1964 Uniform Building Code (UBC)',
#     'Building Code Year': '1964',
#     'Year Completed': '1968',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.7626572',
#     'Longitude': '-122.2538986',
#     'Count': '1'},
#    {'_id': 4,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11210',
#     'Facility Name': 'Alameda Hospital',
#     'City': 'Alameda',
#     'Building Nbr': 'BLD-01281',
#     'Building Name': 'South Wing',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3s',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=83HIS&capID2=00000&capID3=00027&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '3',
#     'Building Code': '1976 California Building Code (CBC)',
#     'Building Code Year': '1976',
#     'Year Completed': '1983',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7626572',
#     'Longitude': '-122.2538986',
#     'Count': '1'},
#    {'_id': 5,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11210',
#     'Facility Name': 'Alameda Hospital',
#     'City': 'Alameda',
#     'Building Nbr': 'BLD-01282',
#     'Building Name': 'Radiology Addition',
#     'Building Status': 'In Service',
#     'SPC Rating *': '4',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=95HIS&capID2=00000&capID3=00031&agencyCode=OSHPD',
#     'Height (ft)': '27',
#     'Stories': '2',
#     'Building Code': '1985 California Building Code (CBC)',
#     'Building Code Year': '1985',
#     'Year Completed': '1995',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7626572',
#     'Longitude': '-122.2538986',
#     'Count': '1'},
#    {'_id': 6,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11210',
#     'Facility Name': 'Alameda Hospital',
#     'City': 'Alameda',
#     'Building Nbr': 'BLD-01283',
#     'Building Name': 'Medical Gas Storage',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=95HIS&capID2=00000&capID3=00032&agencyCode=OSHPD',
#     'Height (ft)': '8.42',
#     'Stories': '1',
#     'Building Code': '1985 California Building Code (CBC)',
#     'Building Code Year': '1985',
#     'Year Completed': '1995',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7626572',
#     'Longitude': '-122.2538986',
#     'Count': '1'},
#    {'_id': 7,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11210',
#     'Facility Name': 'Alameda Hospital',
#     'City': 'Alameda',
#     'Building Nbr': 'BLD-02630',
#     'Building Name': 'Compactor Shed',
#     'Building Status': 'In Service',
#     'SPC Rating *': '4',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=83HIS&capID2=00000&capID3=00048&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '1',
#     'Building Code': '1976 California Building Code (CBC)',
#     'Building Code Year': '1976',
#     'Year Completed': '1983',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7626572',
#     'Longitude': '-122.2538986',
#     'Count': '1'},
#    {'_id': 8,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11210',
#     'Facility Name': 'Alameda Hospital',
#     'City': 'Alameda',
#     'Building Nbr': 'BLD-03120',
#     'Building Name': 'Emergency Room Relocation',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3s',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=87HIS&capID2=00000&capID3=00045&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '1',
#     'Building Code': '1979 California Building Code (CBC)',
#     'Building Code Year': '1979',
#     'Year Completed': '1988',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7626572',
#     'Longitude': '-122.2538986',
#     'Count': '1'},
#    {'_id': 9,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11210',
#     'Facility Name': 'Alameda Hospital',
#     'City': 'Alameda',
#     'Building Nbr': 'BLD-05597',
#     'Building Name': 'LOX Tank',
#     'Building Status': 'Under Construction',
#     'SPC Rating *': 'N/A',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=13CAP&capID2=00000&capID3=003TM&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': None,
#     'Building Code': '2010 California Building Code (CBC)',
#     'Building Code Year': '2010',
#     'Year Completed': '2016',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7626572',
#     'Longitude': '-122.2538986',
#     'Count': '1'},
#    {'_id': 10,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00695',
#     'Building Name': 'Ehman Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=37HIS&capID2=00000&capID3=00001&agencyCode=OSHPD',
#     'Height (ft)': '49.75',
#     'Stories': '4',
#     'Building Code': '1927 Uniform Building Code (UBC)',
#     'Building Code Year': '1927',
#     'Year Completed': '1937',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 11,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00696',
#     'Building Name': 'North Wing',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=52HIS&capID2=00000&capID3=00004&agencyCode=OSHPD',
#     'Height (ft)': '50',
#     'Stories': '4',
#     'Building Code': '1946 Uniform Building Code (UBC)',
#     'Building Code Year': '1946',
#     'Year Completed': '1952',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 12,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00698',
#     'Building Name': 'East Wing',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=64HIS&capID2=00000&capID3=00015&agencyCode=OSHPD',
#     'Height (ft)': '62.5',
#     'Stories': '5',
#     'Building Code': '1961 Uniform Building Code (UBC)',
#     'Building Code Year': '1961',
#     'Year Completed': '1964',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 13,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00699',
#     'Building Name': 'Original West Wing',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=45HIS&capID2=00000&capID3=00001&agencyCode=OSHPD',
#     'Height (ft)': '36',
#     'Stories': '3',
#     'Building Code': '1943 Uniform Building Code (UBC)',
#     'Building Code Year': '1943',
#     'Year Completed': '1945',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 14,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00700',
#     'Building Name': 'West Service Wing - Building 1',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=64HIS&capID2=00000&capID3=00016&agencyCode=OSHPD',
#     'Height (ft)': '33.3',
#     'Stories': '3',
#     'Building Code': '1961 Uniform Building Code (UBC)',
#     'Building Code Year': '1961',
#     'Year Completed': '1965',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 15,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00701',
#     'Building Name': 'Physio-Therapy Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=60HIS&capID2=00000&capID3=00012&agencyCode=OSHPD',
#     'Height (ft)': '12',
#     'Stories': '1',
#     'Building Code': '1952 Uniform Building Code (UBC)',
#     'Building Code Year': '1952',
#     'Year Completed': '1960',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 16,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00702',
#     'Building Name': 'Original Emergency Wing',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=60HIS&capID2=00000&capID3=00013&agencyCode=OSHPD',
#     'Height (ft)': '12',
#     'Stories': '1',
#     'Building Code': '1952 Uniform Building Code (UBC)',
#     'Building Code Year': '1952',
#     'Year Completed': '1960',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 17,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00703',
#     'Building Name': 'Special Procedures Addition',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=74HIS&capID2=00000&capID3=00012&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '1',
#     'Building Code': '1973 California Building Code (CBC)',
#     'Building Code Year': '1973',
#     'Year Completed': '1974',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 18,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00704',
#     'Building Name': 'Emergency Department Expansion',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5s',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=01HIS&capID2=00000&capID3=00013&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '1',
#     'Building Code': '1995 California Building Code (CBC)',
#     'Building Code Year': '1995',
#     'Year Completed': '2002',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 19,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00705',
#     'Building Name': 'Cogeneration Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '4',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=90HIS&capID2=00000&capID3=00024&agencyCode=OSHPD',
#     'Height (ft)': '11.75',
#     'Stories': '1',
#     'Building Code': '1982 California Building Code (CBC)',
#     'Building Code Year': '1982',
#     'Year Completed': '1990',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 20,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00706',
#     'Building Name': 'Emergency Generator Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '4',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=80HIS&capID2=00000&capID3=00499&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '2',
#     'Building Code': '1973 California Building Code (CBC)',
#     'Building Code Year': '1973',
#     'Year Completed': '1982',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 21,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00707',
#     'Building Name': 'Transformer Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=69HIS&capID2=00000&capID3=00013&agencyCode=OSHPD',
#     'Height (ft)': '21.7',
#     'Stories': '2',
#     'Building Code': '1967 Uniform Building Code (UBC)',
#     'Building Code Year': '1967',
#     'Year Completed': '1969',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 22,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-03431',
#     'Building Name': 'South Wing - Phase 2',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=78HIS&capID2=00000&capID3=00055&agencyCode=OSHPD',
#     'Height (ft)': '102.5',
#     'Stories': '6',
#     'Building Code': '1973 California Building Code (CBC)',
#     'Building Code Year': '1973',
#     'Year Completed': '1980',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 23,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-03433',
#     'Building Name': 'West Service Wing - Building 2 - Structurally connected to BLD-00699',
#     'Building Status': 'Not an Independent Building',
#     'SPC Rating *': 'N/A',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=64HIS&capID2=00000&capID3=00062&agencyCode=OSHPD',
#     'Height (ft)': '23',
#     'Stories': '2',
#     'Building Code': '1961 Uniform Building Code (UBC)',
#     'Building Code Year': '1961',
#     'Year Completed': '1965',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 24,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-03434',
#     'Building Name': 'Orig Emergency Wing - East Wing - Structurally connected to BLD-00702',
#     'Building Status': 'Not an Independent Building',
#     'SPC Rating *': 'N/A',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=64HIS&capID2=00000&capID3=00063&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '1',
#     'Building Code': '1961 Uniform Building Code (UBC)',
#     'Building Code Year': '1961',
#     'Year Completed': '1964',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 25,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-05300',
#     'Building Name': 'Patient Care Pavilion',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=11CAP&capID2=00000&capID3=0034R&agencyCode=OSHPD',
#     'Height (ft)': '154.75',
#     'Stories': '12',
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2014',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 26,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-06010',
#     'Building Name': 'New LOX Tank',
#     'Building Status': 'Equipment Yard',
#     'SPC Rating *': 'N/A',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=16CAP&capID2=00000&capID3=0023T&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': None,
#     'Building Code': '2013 California Building Code (CBC)',
#     'Building Code Year': '2013',
#     'Year Completed': '2019',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 27,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11322',
#     'Facility Name': 'Alta Bates Summit Medical Center',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-06060',
#     'Building Name': 'Emergency Generator Yard',
#     'Building Status': 'Equipment Yard',
#     'SPC Rating *': 'N/A',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=16CAP&capID2=00000&capID3=004UR&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': None,
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2014',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8208094',
#     'Longitude': '-122.2630806',
#     'Count': '1'},
#    {'_id': 28,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11338',
#     'Facility Name': 'Alta Bates Summit Medical Center - Summit Campus',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-00708',
#     'Building Name': 'Main Hospital Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=78HIS&capID2=00000&capID3=00013&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '6',
#     'Building Code': '1976 California Building Code (CBC)',
#     'Building Code Year': '1976',
#     'Year Completed': '1978',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8199008',
#     'Longitude': '-122.2643586',
#     'Count': '1'},
#    {'_id': 29,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11338',
#     'Facility Name': 'Alta Bates Summit Medical Center - Summit Campus',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-03443',
#     'Building Name': 'Main Entrance Canopy',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=78HIS&capID2=00000&capID3=00057&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '1',
#     'Building Code': '1976 California Building Code (CBC)',
#     'Building Code Year': '1976',
#     'Year Completed': '1978',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8199008',
#     'Longitude': '-122.2643586',
#     'Count': '1'},
#    {'_id': 30,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11338',
#     'Facility Name': 'Alta Bates Summit Medical Center - Summit Campus',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-03444',
#     'Building Name': 'Bridge at Link',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=78HIS&capID2=00000&capID3=00058&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '2',
#     'Building Code': '1976 California Building Code (CBC)',
#     'Building Code Year': '1976',
#     'Year Completed': '1978',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8199008',
#     'Longitude': '-122.2643586',
#     'Count': '1'},
#    {'_id': 31,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11214',
#     'Facility Name': 'Alta Bates Summit Medical Center-Alta Bates Campus',
#     'City': 'Berkeley',
#     'Building Nbr': 'BLD-01285',
#     'Building Name': 'Admin.',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=59HIS&capID2=00000&capID3=00011&agencyCode=OSHPD',
#     'Height (ft)': '13',
#     'Stories': '1',
#     'Building Code': '1955 Uniform Building Code (UBC)',
#     'Building Code Year': '1955',
#     'Year Completed': '1959',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8559265',
#     'Longitude': '-122.257309',
#     'Count': '1'},
#    {'_id': 32,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11214',
#     'Facility Name': 'Alta Bates Summit Medical Center-Alta Bates Campus',
#     'City': 'Berkeley',
#     'Building Nbr': 'BLD-01286',
#     'Building Name': 'Laundry/Hall of Health',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=59HIS&capID2=00000&capID3=00012&agencyCode=OSHPD',
#     'Height (ft)': '25',
#     'Stories': '2',
#     'Building Code': '1955 Uniform Building Code (UBC)',
#     'Building Code Year': '1955',
#     'Year Completed': '1959',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8559265',
#     'Longitude': '-122.257309',
#     'Count': '1'},
#    {'_id': 33,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11214',
#     'Facility Name': 'Alta Bates Summit Medical Center-Alta Bates Campus',
#     'City': 'Berkeley',
#     'Building Nbr': 'BLD-01287',
#     'Building Name': 'Boiler',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=68HIS&capID2=00000&capID3=00037&agencyCode=OSHPD',
#     'Height (ft)': '25',
#     'Stories': '1',
#     'Building Code': '1961 Uniform Building Code (UBC)',
#     'Building Code Year': '1961',
#     'Year Completed': '1968',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8559265',
#     'Longitude': '-122.257309',
#     'Count': '1'},
#    {'_id': 34,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11214',
#     'Facility Name': 'Alta Bates Summit Medical Center-Alta Bates Campus',
#     'City': 'Berkeley',
#     'Building Nbr': 'BLD-01288',
#     'Building Name': '1968 Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=68HIS&capID2=00000&capID3=00038&agencyCode=OSHPD',
#     'Height (ft)': '83',
#     'Stories': '7',
#     'Building Code': '1961 Uniform Building Code (UBC)',
#     'Building Code Year': '1961',
#     'Year Completed': '1968',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8559265',
#     'Longitude': '-122.257309',
#     'Count': '1'},
#    {'_id': 35,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11214',
#     'Facility Name': 'Alta Bates Summit Medical Center-Alta Bates Campus',
#     'City': 'Berkeley',
#     'Building Nbr': 'BLD-01289',
#     'Building Name': '1975 Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=75HIS&capID2=00000&capID3=00026&agencyCode=OSHPD',
#     'Height (ft)': '67',
#     'Stories': '6',
#     'Building Code': '1970 Uniform Building Code (UBC)',
#     'Building Code Year': '1970',
#     'Year Completed': '1975',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.8559265',
#     'Longitude': '-122.257309',
#     'Count': '1'},
#    {'_id': 36,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11214',
#     'Facility Name': 'Alta Bates Summit Medical Center-Alta Bates Campus',
#     'City': 'Berkeley',
#     'Building Nbr': 'BLD-01290',
#     'Building Name': '1985 Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '4',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=85HIS&capID2=00000&capID3=00017&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '2',
#     'Building Code': '1979 California Building Code (CBC)',
#     'Building Code Year': '1979',
#     'Year Completed': '1988',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8559265',
#     'Longitude': '-122.257309',
#     'Count': '1'},
#    {'_id': 37,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11214',
#     'Facility Name': 'Alta Bates Summit Medical Center-Alta Bates Campus',
#     'City': 'Berkeley',
#     'Building Nbr': 'BLD-01291',
#     'Building Name': 'Electric Service Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '4',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=85HIS&capID2=00000&capID3=00018&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '2',
#     'Building Code': '1979 California Building Code (CBC)',
#     'Building Code Year': '1979',
#     'Year Completed': '1988',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8559265',
#     'Longitude': '-122.257309',
#     'Count': '1'},
#    {'_id': 38,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11214',
#     'Facility Name': 'Alta Bates Summit Medical Center-Alta Bates Campus',
#     'City': 'Berkeley',
#     'Building Nbr': 'BLD-01292',
#     'Building Name': 'Oxygen Tank Enclosure',
#     'Building Status': 'Equipment Yard',
#     'SPC Rating *': 'N/A',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=85HIS&capID2=00000&capID3=00019&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '1',
#     'Building Code': '1979 California Building Code (CBC)',
#     'Building Code Year': '1979',
#     'Year Completed': '1988',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8559265',
#     'Longitude': '-122.257309',
#     'Count': '1'},
#    {'_id': 39,
#     'County Code': '01 - Alameda',
#     'Perm ID': '18180',
#     'Facility Name': 'Eden Medical Center',
#     'City': 'Castro Valley',
#     'Building Nbr': 'BLD-05340',
#     'Building Name': 'Replacement Hospital',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=12CAP&capID2=00000&capID3=001A5&agencyCode=OSHPD',
#     'Height (ft)': '117.5',
#     'Stories': '6',
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2014',
#     'AB 1882 Notice': None,
#     'Latitude': '37.69838',
#     'Longitude': '-122.0873925',
#     'Count': '1'},
#    {'_id': 40,
#     'County Code': '01 - Alameda',
#     'Perm ID': '18180',
#     'Facility Name': 'Eden Medical Center',
#     'City': 'Castro Valley',
#     'Building Nbr': 'BLD-05341',
#     'Building Name': 'Chiller Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=12CAP&capID2=00000&capID3=001A6&agencyCode=OSHPD',
#     'Height (ft)': '18',
#     'Stories': '1',
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2014',
#     'AB 1882 Notice': None,
#     'Latitude': '37.69838',
#     'Longitude': '-122.0873925',
#     'Count': '1'},
#    {'_id': 41,
#     'County Code': '01 - Alameda',
#     'Perm ID': '18180',
#     'Facility Name': 'Eden Medical Center',
#     'City': 'Castro Valley',
#     'Building Nbr': 'BLD-05342',
#     'Building Name': 'Main Entrance Canopy',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=12CAP&capID2=00000&capID3=001A7&agencyCode=OSHPD',
#     'Height (ft)': '17',
#     'Stories': '1',
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2014',
#     'AB 1882 Notice': None,
#     'Latitude': '37.69838',
#     'Longitude': '-122.0873925',
#     'Count': '1'},
#    {'_id': 42,
#     'County Code': '01 - Alameda',
#     'Perm ID': '18180',
#     'Facility Name': 'Eden Medical Center',
#     'City': 'Castro Valley',
#     'Building Nbr': 'BLD-05343',
#     'Building Name': 'Emergency Entrance Canopy',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=12CAP&capID2=00000&capID3=001A8&agencyCode=OSHPD',
#     'Height (ft)': '17',
#     'Stories': '1',
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2014',
#     'AB 1882 Notice': None,
#     'Latitude': '37.69838',
#     'Longitude': '-122.0873925',
#     'Count': '1'},
#    {'_id': 43,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11268',
#     'Facility Name': 'Fairmont Hospital',
#     'City': 'San Leandro',
#     'Building Nbr': 'BLD-01311',
#     'Building Name': 'Building B',
#     'Building Status': 'Skilled Nursing Only',
#     'SPC Rating *': 'N/A',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=30HIS&capID2=00000&capID3=00002&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '3',
#     'Building Code': '1927 Uniform Building Code (UBC)',
#     'Building Code Year': '1927',
#     'Year Completed': '1930',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7100449',
#     'Longitude': '-122.1153183',
#     'Count': '1'},
#    {'_id': 44,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11268',
#     'Facility Name': 'Fairmont Hospital',
#     'City': 'San Leandro',
#     'Building Nbr': 'BLD-01312',
#     'Building Name': 'Building H',
#     'Building Status': 'Delicensed Clinic under OSHPD',
#     'SPC Rating *': 'N/A',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=61HIS&capID2=00000&capID3=00015&agencyCode=OSHPD',
#     'Height (ft)': '23',
#     'Stories': '2',
#     'Building Code': '1955 Uniform Building Code (UBC)',
#     'Building Code Year': '1955',
#     'Year Completed': '1961',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7100449',
#     'Longitude': '-122.1153183',
#     'Count': '1'},
#    {'_id': 45,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11288',
#     'Facility Name': 'Highland Hospital',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-01315',
#     'Building Name': 'Critical Care Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=06HIS&capID2=00000&capID3=00026&agencyCode=OSHPD',
#     'Height (ft)': '74.48',
#     'Stories': '5',
#     'Building Code': '1995 California Building Code (CBC)',
#     'Building Code Year': '1995',
#     'Year Completed': '2006',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7991754',
#     'Longitude': '-122.2310563',
#     'Count': '1'},
#    {'_id': 46,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11288',
#     'Facility Name': 'Highland Hospital',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-02957',
#     'Building Name': 'New Acute Care Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=73HIS&capID2=00000&capID3=00171&agencyCode=OSHPD',
#     'Height (ft)': '137.75',
#     'Stories': '9',
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2019',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7991754',
#     'Longitude': '-122.2310563',
#     'Count': '1'},
#    {'_id': 47,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11288',
#     'Facility Name': 'Highland Hospital',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-06256',
#     'Building Name': 'Critical Care Parking Structure',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=17CAP&capID2=00000&capID3=005VZ&agencyCode=OSHPD',
#     'Height (ft)': '50.04',
#     'Stories': '6',
#     'Building Code': '1995 California Building Code (CBC)',
#     'Building Code Year': '1995',
#     'Year Completed': '2006',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7991754',
#     'Longitude': '-122.2310563',
#     'Count': '1'},
#    {'_id': 48,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11288',
#     'Facility Name': 'Highland Hospital',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-06880',
#     'Building Name': 'Oxygen Yard',
#     'Building Status': 'Equipment Yard',
#     'SPC Rating *': 'N/A',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=22CAP&capID2=00000&capID3=0021G&agencyCode=OSHPD',
#     'Height (ft)': '0',
#     'Stories': None,
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2019',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7991754',
#     'Longitude': '-122.2310563',
#     'Count': '1'},
#    {'_id': 49,
#     'County Code': '01 - Alameda',
#     'Perm ID': '14509',
#     'Facility Name': 'Kaiser Foundation Hospital - Fremont',
#     'City': 'Fremont',
#     'Building Nbr': 'BLD-02489',
#     'Building Name': 'Hospital Patient Wing North',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=95HIS&capID2=00000&capID3=00065&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '2',
#     'Building Code': '1989 California Building Code (CBC)',
#     'Building Code Year': '1989',
#     'Year Completed': '1995',
#     'AB 1882 Notice': None,
#     'Latitude': '37.5518335',
#     'Longitude': '-121.9776935',
#     'Count': '1'},
#    {'_id': 50,
#     'County Code': '01 - Alameda',
#     'Perm ID': '14509',
#     'Facility Name': 'Kaiser Foundation Hospital - Fremont',
#     'City': 'Fremont',
#     'Building Nbr': 'BLD-02490',
#     'Building Name': 'Hospital Patient Wing South',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=95HIS&capID2=00000&capID3=00066&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '2',
#     'Building Code': '1989 California Building Code (CBC)',
#     'Building Code Year': '1989',
#     'Year Completed': '1995',
#     'AB 1882 Notice': None,
#     'Latitude': '37.5518335',
#     'Longitude': '-121.9776935',
#     'Count': '1'},
#    {'_id': 51,
#     'County Code': '01 - Alameda',
#     'Perm ID': '14509',
#     'Facility Name': 'Kaiser Foundation Hospital - Fremont',
#     'City': 'Fremont',
#     'Building Nbr': 'BLD-02491',
#     'Building Name': 'Hospital North',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=95HIS&capID2=00000&capID3=00067&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '2',
#     'Building Code': '1989 California Building Code (CBC)',
#     'Building Code Year': '1989',
#     'Year Completed': '1995',
#     'AB 1882 Notice': None,
#     'Latitude': '37.5518335',
#     'Longitude': '-121.9776935',
#     'Count': '1'},
#    {'_id': 52,
#     'County Code': '01 - Alameda',
#     'Perm ID': '14509',
#     'Facility Name': 'Kaiser Foundation Hospital - Fremont',
#     'City': 'Fremont',
#     'Building Nbr': 'BLD-02492',
#     'Building Name': 'Hospital South',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=95HIS&capID2=00000&capID3=00068&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '2',
#     'Building Code': '1989 California Building Code (CBC)',
#     'Building Code Year': '1989',
#     'Year Completed': '1995',
#     'AB 1882 Notice': None,
#     'Latitude': '37.5518335',
#     'Longitude': '-121.9776935',
#     'Count': '1'},
#    {'_id': 53,
#     'County Code': '01 - Alameda',
#     'Perm ID': '14509',
#     'Facility Name': 'Kaiser Foundation Hospital - Fremont',
#     'City': 'Fremont',
#     'Building Nbr': 'BLD-02493',
#     'Building Name': 'Central Plant',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=95HIS&capID2=00000&capID3=00069&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '1',
#     'Building Code': '1989 California Building Code (CBC)',
#     'Building Code Year': '1989',
#     'Year Completed': '1995',
#     'AB 1882 Notice': None,
#     'Latitude': '37.5518335',
#     'Longitude': '-121.9776935',
#     'Count': '1'},
#    {'_id': 54,
#     'County Code': '01 - Alameda',
#     'Perm ID': '14509',
#     'Facility Name': 'Kaiser Foundation Hospital - Fremont',
#     'City': 'Fremont',
#     'Building Nbr': 'BLD-02494',
#     'Building Name': 'General Services Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3s',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=90HIS&capID2=00000&capID3=00058&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '1',
#     'Building Code': '1989 California Building Code (CBC)',
#     'Building Code Year': '1989',
#     'Year Completed': '1991',
#     'AB 1882 Notice': None,
#     'Latitude': '37.5518335',
#     'Longitude': '-121.9776935',
#     'Count': '1'},
#    {'_id': 55,
#     'County Code': '01 - Alameda',
#     'Perm ID': '14509',
#     'Facility Name': 'Kaiser Foundation Hospital - Fremont',
#     'City': 'Fremont',
#     'Building Nbr': 'BLD-06569',
#     'Building Name': 'CUP',
#     'Building Status': 'Proposed',
#     'SPC Rating *': '5s',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=19CAP&capID2=00000&capID3=00B5F&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': None,
#     'Building Code': '2019 California Building Code (CBC)',
#     'Building Code Year': '2019',
#     'Year Completed': None,
#     'AB 1882 Notice': None,
#     'Latitude': '37.5518335',
#     'Longitude': '-121.9776935',
#     'Count': '1'},
#    {'_id': 56,
#     'County Code': '01 - Alameda',
#     'Perm ID': '14509',
#     'Facility Name': 'Kaiser Foundation Hospital - Fremont',
#     'City': 'Fremont',
#     'Building Nbr': 'BLD-06741',
#     'Building Name': 'Emergency Department',
#     'Building Status': 'Proposed',
#     'SPC Rating *': '5s',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=21CAP&capID2=00000&capID3=002RU&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': None,
#     'Building Code': '2019 California Building Code (CBC)',
#     'Building Code Year': '2019',
#     'Year Completed': None,
#     'AB 1882 Notice': None,
#     'Latitude': '37.5518335',
#     'Longitude': '-121.9776935',
#     'Count': '1'},
#    {'_id': 57,
#     'County Code': '01 - Alameda',
#     'Perm ID': '18206',
#     'Facility Name': 'Kaiser Foundation Hospital - Oakland/Richmond',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-02986',
#     'Building Name': 'Hospital',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=73HIS&capID2=00000&capID3=00173&agencyCode=OSHPD',
#     'Height (ft)': '192',
#     'Stories': '12',
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2014',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8233092',
#     'Longitude': '-122.2592711',
#     'Count': '1'},
#    {'_id': 58,
#     'County Code': '01 - Alameda',
#     'Perm ID': '18206',
#     'Facility Name': 'Kaiser Foundation Hospital - Oakland/Richmond',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-02987',
#     'Building Name': 'Central Plant',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=73HIS&capID2=00000&capID3=00174&agencyCode=OSHPD',
#     'Height (ft)': '46.33',
#     'Stories': '2',
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2014',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8233092',
#     'Longitude': '-122.2592711',
#     'Count': '1'},
#    {'_id': 59,
#     'County Code': '01 - Alameda',
#     'Perm ID': '18206',
#     'Facility Name': 'Kaiser Foundation Hospital - Oakland/Richmond',
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-05716',
#     'Building Name': 'Loading Dock and Plaza',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=14CAP&capID2=00000&capID3=0009N&agencyCode=OSHPD',
#     'Height (ft)': '17',
#     'Stories': '1',
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2014',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8233092',
#     'Longitude': '-122.2592711',
#     'Count': '1'},
#    {'_id': 60,
#     'County Code': '01 - Alameda',
#     'Perm ID': '18186',
#     'Facility Name': 'Kaiser Foundation Hospital - San Leandro',
#     'City': 'San Leandro',
#     'Building Nbr': 'BLD-03481',
#     'Building Name': 'Templated Hospital Project',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=73HIS&capID2=00000&capID3=00420&agencyCode=OSHPD',
#     'Height (ft)': '92',
#     'Stories': '6',
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2015',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7062596',
#     'Longitude': '-122.1692482',
#     'Count': '1'},
#    {'_id': 61,
#     'County Code': '01 - Alameda',
#     'Perm ID': '18186',
#     'Facility Name': 'Kaiser Foundation Hospital - San Leandro',
#     'City': 'San Leandro',
#     'Building Nbr': 'BLD-03482',
#     'Building Name': 'Central Utility Plant',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=73HIS&capID2=00000&capID3=00421&agencyCode=OSHPD',
#     'Height (ft)': '40',
#     'Stories': '2',
#     'Building Code': '2007 California Building Code (CBC)',
#     'Building Code Year': '2007',
#     'Year Completed': '2014',
#     'AB 1882 Notice': None,
#     'Latitude': '37.7062596',
#     'Longitude': '-122.1692482',
#     'Count': '1'},
#    {'_id': 62,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11321',
#     'Facility Name': 'Kindred Hospital - San Francisco Bay Area',
#     'City': 'San Leandro',
#     'Building Nbr': 'BLD-00692',
#     'Building Name': 'Original Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=61HIS&capID2=00000&capID3=00007&agencyCode=OSHPD',
#     'Height (ft)': '51.5',
#     'Stories': '4',
#     'Building Code': '1958 Uniform Building Code (UBC)',
#     'Building Code Year': '1958',
#     'Year Completed': '1961',
# ...
#     'Year Completed': '1983',
#     'AB 1882 Notice': None,
#     'Latitude': '37.6769028',
#     'Longitude': '-121.7817917',
#     'Count': '1'},
#    {'_id': 82,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11363',
#     'Facility Name': 'Stanford Health Care Tri-Valley',
#     'City': 'Livermore',
#     'Building Nbr': 'BLD-03085',
#     'Building Name': 'Building D: Service Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '4s',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=82HIS&capID2=00000&capID3=00046&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '1',
#     'Building Code': '1979 California Building Code (CBC)',
#     'Building Code Year': '1979',
#     'Year Completed': '1982',
#     'AB 1882 Notice': None,
#     'Latitude': '37.6769028',
#     'Longitude': '-121.7817917',
#     'Count': '1'},
#    {'_id': 83,
#     'County Code': '01 - Alameda',
#     'Perm ID': '16632',
#     'Facility Name': 'Stanford Health Care Tri-Valley',
#     'City': 'Pleasanton',
#     'Building Nbr': 'BLD-02532',
#     'Building Name': 'Hospital  Ambulatory Care & Inc. II',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=94HIS&capID2=00000&capID3=00064&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '2',
#     'Building Code': '1985 California Building Code (CBC)',
#     'Building Code Year': '1985',
#     'Year Completed': '1994',
#     'AB 1882 Notice': None,
#     'Latitude': '37.6939774',
#     'Longitude': '-121.8806839',
#     'Count': '1'},
#    {'_id': 84,
#     'County Code': '01 - Alameda',
#     'Perm ID': '16632',
#     'Facility Name': 'Stanford Health Care Tri-Valley',
#     'City': 'Pleasanton',
#     'Building Nbr': 'BLD-02533',
#     'Building Name': 'Central Plant',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=91HIS&capID2=00000&capID3=00056&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '2',
#     'Building Code': '1989 California Building Code (CBC)',
#     'Building Code Year': '1989',
#     'Year Completed': '1994',
#     'AB 1882 Notice': None,
#     'Latitude': '37.6939774',
#     'Longitude': '-121.8806839',
#     'Count': '1'},
#    {'_id': 85,
#     'County Code': '01 - Alameda',
#     'Perm ID': '16632',
#     'Facility Name': 'Stanford Health Care Tri-Valley',
#     'City': 'Pleasanton',
#     'Building Nbr': 'BLD-02534',
#     'Building Name': 'Valleycare (New) Addition',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=01HIS&capID2=00000&capID3=00030&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '4',
#     'Building Code': '1995 California Building Code (CBC)',
#     'Building Code Year': '1995',
#     'Year Completed': '2003',
#     'AB 1882 Notice': None,
#     'Latitude': '37.6939774',
#     'Longitude': '-121.8806839',
#     'Count': '1'},
#    {'_id': 86,
#     'County Code': '01 - Alameda',
#     'Perm ID': '16632',
#     'Facility Name': 'Stanford Health Care Tri-Valley',
#     'City': 'Pleasanton',
#     'Building Nbr': 'BLD-02699',
#     'Building Name': 'Arcade - Phase I - Portion 1',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=86HIS&capID2=00000&capID3=00048&agencyCode=OSHPD',
#     'Height (ft)': '25',
#     'Stories': '1',
#     'Building Code': '1982 Uniform Building Code (UBC)',
#     'Building Code Year': '1982',
#     'Year Completed': '1986',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.6939774',
#     'Longitude': '-121.8806839',
#     'Count': '1'},
#    {'_id': 87,
#     'County Code': '01 - Alameda',
#     'Perm ID': '16632',
#     'Facility Name': 'Stanford Health Care Tri-Valley',
#     'City': 'Pleasanton',
#     'Building Nbr': 'BLD-02700',
#     'Building Name': 'Arcade - Phase II - Portion 1',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=89HIS&capID2=00000&capID3=00041&agencyCode=OSHPD',
#     'Height (ft)': '25',
#     'Stories': '1',
#     'Building Code': '1985 Uniform Building Code (UBC)',
#     'Building Code Year': '1985',
#     'Year Completed': '1989',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.6939774',
#     'Longitude': '-121.8806839',
#     'Count': '1'},
#    {'_id': 88,
#     'County Code': '01 - Alameda',
#     'Perm ID': '16632',
#     'Facility Name': 'Stanford Health Care Tri-Valley',
#     'City': 'Pleasanton',
#     'Building Nbr': 'BLD-02701',
#     'Building Name': 'Porte Cochere',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=01HIS&capID2=00000&capID3=00034&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '1',
#     'Building Code': '1995 California Building Code (CBC)',
#     'Building Code Year': '1995',
#     'Year Completed': '2003',
#     'AB 1882 Notice': None,
#     'Latitude': '37.6939774',
#     'Longitude': '-121.8806839',
#     'Count': '1'},
#    {'_id': 89,
#     'County Code': '01 - Alameda',
#     'Perm ID': '16632',
#     'Facility Name': 'Stanford Health Care Tri-Valley',
#     'City': 'Pleasanton',
#     'Building Nbr': 'BLD-02901',
#     'Building Name': 'Arcade - Phase I - Portion 2',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=86HIS&capID2=00000&capID3=00053&agencyCode=OSHPD',
#     'Height (ft)': '25',
#     'Stories': '1',
#     'Building Code': '1982 Uniform Building Code (UBC)',
#     'Building Code Year': '1982',
#     'Year Completed': '1986',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.6939774',
#     'Longitude': '-121.8806839',
#     'Count': '1'},
#    {'_id': 90,
#     'County Code': '01 - Alameda',
#     'Perm ID': '16632',
#     'Facility Name': 'Stanford Health Care Tri-Valley',
#     'City': 'Pleasanton',
#     'Building Nbr': 'BLD-02902',
#     'Building Name': 'Arcade - Phase I - Portion 3',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=86HIS&capID2=00000&capID3=00054&agencyCode=OSHPD',
#     'Height (ft)': '25',
#     'Stories': '1',
#     'Building Code': '1982 Uniform Building Code (UBC)',
#     'Building Code Year': '1982',
#     'Year Completed': '1986',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.6939774',
#     'Longitude': '-121.8806839',
#     'Count': '1'},
#    {'_id': 91,
#     'County Code': '01 - Alameda',
#     'Perm ID': '16632',
#     'Facility Name': 'Stanford Health Care Tri-Valley',
#     'City': 'Pleasanton',
#     'Building Nbr': 'BLD-02903',
#     'Building Name': 'Arcade - Phase II - Portion 2',
#     'Building Status': 'In Service',
#     'SPC Rating *': '2',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=89HIS&capID2=00000&capID3=00046&agencyCode=OSHPD',
#     'Height (ft)': '25',
#     'Stories': '1',
#     'Building Code': '1985 Uniform Building Code (UBC)',
#     'Building Code Year': '1985',
#     'Year Completed': '1989',
#     'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#     'Latitude': '37.6939774',
#     'Longitude': '-121.8806839',
#     'Count': '1'},
#    {'_id': 92,
#     'County Code': '01 - Alameda',
#     'Perm ID': '16632',
#     'Facility Name': 'Stanford Health Care Tri-Valley',
#     'City': 'Pleasanton',
#     'Building Nbr': 'BLD-06430',
#     'Building Name': 'Ambulance Drop Off Canopy',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=18CAP&capID2=00000&capID3=009QB&agencyCode=OSHPD',
#     'Height (ft)': '13.57',
#     'Stories': '1',
#     'Building Code': '2016 California Building Code (CBC)',
#     'Building Code Year': '2016',
#     'Year Completed': '2020',
#     'AB 1882 Notice': None,
#     'Latitude': '37.6939774',
#     'Longitude': '-121.8806839',
#     'Count': '1'},
#    {'_id': 93,
#     'County Code': '01 - Alameda',
#     'Perm ID': '16632',
#     'Facility Name': 'Stanford Health Care Tri-Valley',
#     'City': 'Pleasanton',
#     'Building Nbr': 'BLD-06566',
#     'Building Name': 'Emergency Generator Set',
#     'Building Status': 'Under Construction',
#     'SPC Rating *': 'N/A',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=19CAP&capID2=00000&capID3=00AUZ&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': None,
#     'Building Code': '2016 California Building Code (CBC)',
#     'Building Code Year': '2016',
#     'Year Completed': None,
#     'AB 1882 Notice': None,
#     'Latitude': '37.6939774',
#     'Longitude': '-121.8806839',
#     'Count': '1'},
#    {'_id': 94,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11242',
#     'Facility Name': "UCSF Benioff Children's Hospital Oakland",
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-01293',
#     'Building Name': 'Cardiac Cath Lab - MPOE',
#     'Building Status': 'In Service',
#     'SPC Rating *': '5',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=94HIS&capID2=00000&capID3=00034&agencyCode=OSHPD',
#     'Height (ft)': '12',
#     'Stories': '1',
#     'Building Code': '1992 California Building Code (CBC)',
#     'Building Code Year': '1992',
#     'Year Completed': '1994',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8368568',
#     'Longitude': '-122.2671051',
#     'Count': '1'},
#    {'_id': 95,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11242',
#     'Facility Name': "UCSF Benioff Children's Hospital Oakland",
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-01294',
#     'Building Name': 'Patient Tower',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=80HIS&capID2=00000&capID3=00509&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '5',
#     'Building Code': '1976 California Building Code (CBC)',
#     'Building Code Year': '1976',
#     'Year Completed': '1982',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8368568',
#     'Longitude': '-122.2671051',
#     'Count': '1'},
#    {'_id': 96,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11242',
#     'Facility Name': "UCSF Benioff Children's Hospital Oakland",
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-01295',
#     'Building Name': 'West Site Plant',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=82HIS&capID2=00000&capID3=00015&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '2',
#     'Building Code': '1976 California Building Code (CBC)',
#     'Building Code Year': '1976',
#     'Year Completed': '1982',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8368568',
#     'Longitude': '-122.2671051',
#     'Count': '1'},
#    {'_id': 97,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11242',
#     'Facility Name': "UCSF Benioff Children's Hospital Oakland",
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-01296',
#     'Building Name': 'Cafeteria Addition',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=88HIS&capID2=00000&capID3=00028&agencyCode=OSHPD',
#     'Height (ft)': '33.25',
#     'Stories': '1',
#     'Building Code': '1985 California Building Code (CBC)',
#     'Building Code Year': '1985',
#     'Year Completed': '1988',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8368568',
#     'Longitude': '-122.2671051',
#     'Count': '1'},
#    {'_id': 98,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11242',
#     'Facility Name': "UCSF Benioff Children's Hospital Oakland",
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-01297',
#     'Building Name': 'Diagnostic & Treatment Building',
#     'Building Status': 'In Service',
#     'SPC Rating *': '3',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=61HIS&capID2=00000&capID3=00014&agencyCode=OSHPD',
#     'Height (ft)': None,
#     'Stories': '3',
#     'Building Code': '1958 Uniform Building Code (UBC)',
#     'Building Code Year': '1958',
#     'Year Completed': '1961',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8368568',
#     'Longitude': '-122.2671051',
#     'Count': '1'},
#    {'_id': 99,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11242',
#     'Facility Name': "UCSF Benioff Children's Hospital Oakland",
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-01298',
#     'Building Name': 'B/C Wing',
#     'Building Status': 'In Service',
#     'SPC Rating *': '1',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=46HIS&capID2=00000&capID3=00001&agencyCode=OSHPD',
#     'Height (ft)': '50',
#     'Stories': '4',
#     'Building Code': '1943 Uniform Building Code (UBC)',
#     'Building Code Year': '1943',
#     'Year Completed': '1946',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8368568',
#     'Longitude': '-122.2671051',
#     'Count': '1'},
#    {'_id': 100,
#     'County Code': '01 - Alameda',
#     'Perm ID': '11242',
#     'Facility Name': "UCSF Benioff Children's Hospital Oakland",
#     'City': 'Oakland',
#     'Building Nbr': 'BLD-01299',
#     'Building Name': 'A/B Wing',
#     'Building Status': 'In Service',
#     'SPC Rating *': '1',
#     'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=28HIS&capID2=00000&capID3=00005&agencyCode=OSHPD',
#     'Height (ft)': '50',
#     'Stories': '4',
#     'Building Code': '1927 Uniform Building Code (UBC)',
#     'Building Code Year': '1927',
#     'Year Completed': '1928',
#     'AB 1882 Notice': None,
#     'Latitude': '37.8368568',
#     'Longitude': '-122.2671051',
#     'Count': '1'}],
#   'fields': [{'id': '_id', 'type': 'int'},
#    {'id': 'County Code', 'type': 'text'},
#    {'id': 'Perm ID', 'type': 'text'},
#    {'id': 'Facility Name', 'type': 'text'},
#    {'id': 'City', 'type': 'text'},
#    {'id': 'Building Nbr', 'type': 'text'},
#    {'id': 'Building Name', 'type': 'text'},
#    {'id': 'Building Status', 'type': 'text'},
#    {'id': 'SPC Rating *', 'type': 'text'},
#    {'id': 'Building URL', 'type': 'text'},
#    {'id': 'Height (ft)', 'type': 'text'},
#    {'id': 'Stories', 'type': 'text'},
#    {'id': 'Building Code', 'type': 'text'},
#    {'id': 'Building Code Year', 'type': 'text'},
#    {'id': 'Year Completed', 'type': 'text'},
#    {'id': 'AB 1882 Notice', 'type': 'text'},
#    {'id': 'Latitude', 'type': 'text'},
#    {'id': 'Longitude', 'type': 'text'},
#    {'id': 'Count', 'type': 'text'}],
#   '_links': {'start': '/api/3/action/datastore_search?resource_id=d97adf28-ebaf-4204-a29e-bb6bdb7f96b9',
#    'next': '/api/3/action/datastore_search?resource_id=d97adf28-ebaf-4204-a29e-bb6bdb7f96b9&offset=100'},
#   'total': 3982,
#   'total_was_estimated': False}}

# %% [markdown]
# ### 1.2 Parse the obtained data
# Parse the obtained data to get the **first** relevant data value or record from your JSON file.
#
# **Note:** Please ensure the result you obtain is in text and is relevant to hospital building data.

# %%
#Fill in - get the first data record/value from the JSON results
data_api_json['result']['records'][1]
# Out:
# {'_id': 2,
#  'County Code': '01 - Alameda',
#  'Perm ID': '11210',
#  'Facility Name': 'Alameda Hospital',
#  'City': 'Alameda',
#  'Building Nbr': 'BLD-01279',
#  'Building Name': 'Stephens Wing',
#  'Building Status': 'In Service',
#  'SPC Rating *': '2',
#  'Building URL': 'https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&TabName=Permits&capID1=56HIS&capID2=00000&capID3=00012&agencyCode=OSHPD',
#  'Height (ft)': '35',
#  'Stories': '3',
#  'Building Code': '1952 Uniform Building Code (UBC)',
#  'Building Code Year': '1952',
#  'Year Completed': '1956',
#  'AB 1882 Notice': 'This building does not significantly jeopardize life, but may not be repairable or functional following an earthquake.',
#  'Latitude': '37.7626572',
#  'Longitude': '-122.2538986',
#  'Count': '1'}

# %% [markdown]
# What data did you see in the output value?
# Its about a facility named Alameda Hospital and details about it. Such as location, year completed, building number and building names.

# %% [markdown]
# ## 2. Extract a dataset via manual download

# %% [markdown]
# ### 2.1 Download a dataset manually
# We provided you a csv file `hospital_building_data.csv`. You can think that we pre-downloaded the data for you.
#
# Load the dataset into this notebook.

# %%
#FILL IN - load a dataset that was downloaded manually into a dataframe
df = pd.read_csv('hospital_building_data.csv')
df.head()
# Out:
#     County Code  Perm ID     Facility Name     City Building Nbr  \
# 0  01 - Alameda    11210  Alameda Hospital  Alameda    BLD-01278
# 1  01 - Alameda    11210  Alameda Hospital  Alameda    BLD-01279
# 2  01 - Alameda    11210  Alameda Hospital  Alameda    BLD-01280
# 3  01 - Alameda    11210  Alameda Hospital  Alameda    BLD-01281
# 4  01 - Alameda    11210  Alameda Hospital  Alameda    BLD-01282
#
#         Building Name                 Building Status SPC Rating *  \
# 0   Original Hospital  No Gen Acute Care - OSHPD Bldg          NaN
# 1       Stephens Wing                      In Service            2
# 2           West Wing                      In Service            2
# 3          South Wing                      In Service           3s
# 4  Radiology Addition                      In Service           5s
#
#                                         Building URL  Height (ft)  Stories  \
# 0  https://esp.oshpd.ca.gov/CitizenAccess/Cap/Cap...        44.17      4.0
# 1  https://esp.oshpd.ca.gov/CitizenAccess/Cap/Cap...        35.00      3.0
# 2  https://esp.oshpd.ca.gov/CitizenAccess/Cap/Cap...          NaN      2.0
# 3  https://esp.oshpd.ca.gov/CitizenAccess/Cap/Cap...          NaN      3.0
# 4  https://esp.oshpd.ca.gov/CitizenAccess/Cap/Cap...          NaN      2.0
#
#                          Building Code  Building Code Year  Year Completed  \
# 0                              Unknown                 NaN          1926.0
# 1     1952 Uniform Building Code (UBC)              1952.0          1956.0
# 2     1964 Uniform Building Code (UBC)              1964.0          1968.0
# 3  1976 California Building Code (CBC)              1976.0          1983.0
# 4  1985 California Building Code (CBC)              1985.0          1995.0
#
#                                       AB 1882 Notice   Latitude   Longitude  \
# 0                                                NaN  37.762657 -122.253899
# 1  This building does not significantly jeopardiz...  37.762657 -122.253899
# 2  This building does not significantly jeopardiz...  37.762657 -122.253899
# 3                                                NaN  37.762657 -122.253899
# 4                                                NaN  37.762657 -122.253899
#
#    Count
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ### 2.2 Parse the obtained data
# Parse the obtained data to get the **first** relevant data value or record from your manually downloaded dataset.
#
# **Note:** Please ensure the result you obtain is relevant to the hospital building data.

# %%
#Fill in - get the first data record/value from the manually downloaded file
df.iloc[1]
# Out:
# County Code                                                01 - Alameda
# Perm ID                                                           11210
# Facility Name                                          Alameda Hospital
# City                                                            Alameda
# Building Nbr                                                  BLD-01279
# Building Name                                             Stephens Wing
# Building Status                                              In Service
# SPC Rating *                                                          2
# Building URL          https://esp.oshpd.ca.gov/CitizenAccess/Cap/Cap...
# Height (ft)                                                        35.0
# Stories                                                             3.0
# Building Code                          1952 Uniform Building Code (UBC)
# Building Code Year                                               1952.0
# Year Completed                                                   1956.0
# AB 1882 Notice        This building does not significantly jeopardiz...
# Latitude                                                      37.762657
# Longitude                                                   -122.253899
# Count                                                                 1
# Name: 1, dtype: object

# %% [markdown]
# What data did you see in the output? Is that the same with the data you gathered from the API?
# Yes, I see the same record and data about the Alameda Hospital record.

# %% [markdown]
# ## 3. Extract a dataset via scraping

# %% [markdown]
# ### 3.1 Extract your dataset via scraping
# Data webpage url:
#
# https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9
#
# Extract your dataset via scraping using `requests`, and `BeautifulSoup`.

# %%
##FILL IN 
#Extract a dataset via scraping
response = requests.get('https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9')
#Raise an exception if we made a request resulting in an error
response.raise_for_status()
#Access the content of the response in Unicode
response_text = response.text

# %%
#FILL IN
# Use BeautifulSoup to parse the result
bs = BeautifulSoup(response_text)
# Print the prettified version
bs.prettify()
# Out:
# /opt/venv/lib/python3.10/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# '<?xml version="1.0" encoding="utf-8" standalone="yes"?>\n<feed xml:base="https://data.chhs.ca.gov/datastore/odata3.0/" xmlns="http://www.w3.org/2005/Atom" xmlns:d="http://schemas.microsoft.com/ado/2007/08/dataservices" xmlns:m="http://schemas.microsoft.com/ado/2007/08/dataservices/metadata">\n <title type="text">\n  Hospital Building Data (CSV)\n </title>\n <id>\n  https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9\n </id>\n <updated>\n  2024-05-23T18:17:35.464040Z\n </updated>\n <link href="https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9" rel="self" title="d97adf28-ebaf-4204-a29e-bb6bdb7f96b9"/>\n <entry>\n  <id>\n   https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(1)\n  </id>\n  <title type="text">\n   Row 1\n  </title>\n  <updated>\n   2024-05-23T18:17:35.464040Z\n  </updated>\n  <author>\n   <name>\n    ckan\n   </name>\n  </author>\n  <category scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9">\n  </category>\n  <content type="application/xml">\n   <m:properties>\n    <d:_id m:type="Edm.String">\n     1\n    </d:_id>\n    <d:countycode m:type="Edm.String">\n     01 - Alameda\n    </d:countycode>\n    <d:permid m:type="Edm.String">\n     11210\n    </d:permid>\n    <d:facilityname m:type="Edm.String">\n     Alameda Hospital\n    </d:facilityname>\n    <d:city m:type="Edm.String">\n     Alameda\n    </d:city>\n    <d:buildingnbr m:type="Edm.String">\n     BLD-01278\n    </d:buildingnbr>\n    <d:buildingname m:type="Edm.String">\n     Original Hospital\n    </d:buildingname>\n    <d:buildingstatus m:type="Edm.String">\n     No Gen Acute Care - OSHPD Bldg\n    </d:buildingstatus>\n    <d:spcrating m:type="Edm.String">\n     N/A\n    </d:spcrating>\n    <d:buildingurl m:type="Edm.String">\n     https://esp.oshpd.ca.gov/CitizenAccess/Cap/CapDetail.aspx?Module=Permits&amp;TabName=Permits&amp;capID1=26HIS&amp;capID2=00000&amp;capID3=00002&amp;agencyCode=OSHPD\n    </d:buildingurl>\n    <d:heightft m:type="Edm.String">\n     44.17\n    </d:heightft>\n    <d:stories m:type="Edm.String">\n     4\n    </d:stories>\n    <d:buildingcode m:type="Edm.String">\n     Unknown\n    </d:buildingcode>\n    <d:buildingcodeyear m:null="true" m:type="Edm.String">\n    </d:buildingcodeyear>\n    <d:yearcompleted m:type="Edm.String">\n     1926\n    </d:yearcompleted>\n    <d:ab1882notice m:null="true" m:type="Edm.String">\n    </d:ab1882notice>\n    <d:latitude m:type="Edm.String">\n     37.7626572\n    </d:latitude>\n    <d:longitude m:type="Edm.String">\n     -122.2538986\n    </d:longitude>\n    <d:count m:type="Edm.String">\n     1\n    </d:count>\n   </m:properties>\n  </content>\n </entry>\n <entry>\n  <id>\n   https://data.chhs.ca.gov/datastore/odata3.0/d97adf28-ebaf-4204-a29e-bb6bdb7f96b9(2)\n  </id>\n  <title type="text">\n   Row 2\n  </title>\n  <updated>\n   2024-05-23T18:17:35.464040Z\n  </updated>\n  <author>\n   <name>\n    ckan\n   </name>\n  </author>\n  <category scheme="http://schemas.microsoft.com/ado/2007/08/dataservices/scheme" term="ckan.odata.d97adf28-ebaf-4204-a29e-bb6bdb7f96b9">\n  </category>\n  <content type="application/xml">\n   <m:properties>\n    <d:_id m:type="Edm.String">\n     2\n    </d:_id>\n    <d:countycode m:type="Edm.String">\n     01 - Alameda\n    </d:countycode>\n    <d:permid m:type="Edm.String">\n     11210\n    </d:permid>\n    <d:facilityname m:type="Edm.String">\n     Alameda Hospital\n    </d:facilityname>\n    <d:city m:type="Edm.String">\n     Alameda\n    </d:city>\n    <d:buildingnbr m:type="Edm.String">\n     BLD-01279\n    </d:buildingnbr>\n    <d:buildingname m:type="Edm.String">\n     Stephens Wing\n    </d:buildingname>\n    <d:buildingstatus m:type="Edm.String">\n     In Service\n    </d:buildingstatus>\n    <d:spcrating m:type="Edm.String">\n     2\n    </d:spcrating>\n    <d:buildingurl m:type="Edm.String">\n     https: ...

# %% [markdown]
# ### 3.2 Parse the obtained data
# **Note:** Please ensure the result you obtain is in text (not with HTML tags) and is relevant to the hospital buidling data. Hint: you can use the `find_all()` method with tags like `d:buildingname`, `d:buildingcode`, etc.

# %%
#FILL IN - parse specific records from scraped data

for buildingname in bs.find_all("d:buildingname"):
    print(buildingname.text)
# Out:
# Original Hospital
# Stephens Wing
# West Wing
# South Wing
# Radiology Addition
# Medical Gas Storage
# Compactor Shed
# Emergency Room Relocation
# LOX Tank
# Ehman Building
# North Wing
# East Wing
# Original West Wing
# West Service Wing - Building 1
# Physio-Therapy Building
# Original Emergency Wing
# Special Procedures Addition
# Emergency Department Expansion
# Cogeneration Building
# Emergency Generator Building
# Transformer Building
# South Wing - Phase 2
# West Service Wing - Building 2 - Structurally connected to BLD-00699
# Orig Emergency Wing - East Wing - Structurally connected to BLD-00702
# Patient Care Pavilion
# New LOX Tank
# Emergency Generator Yard
# Main Hospital Building
# Main Entrance Canopy
# Bridge at Link
# Admin.
# Laundry/Hall of Health
# Boiler
# 1968 Building
# 1975 Building
# 1985 Building
# Electric Service Building
# Oxygen Tank Enclosure
# Replacement Hospital
# Chiller Building
# Main Entrance Canopy
# Emergency Entrance Canopy
# Building B
# Building H
# Critical Care Building
# New Acute Care Building
# Critical Care Parking Structure
# Oxygen Yard
# Hospital Patient Wing North
# Hospital Patient Wing South
# Hospital North
# Hospital South
# Central Plant
# General Services Building
# CUP
# Emergency Department
# Hospital
# Central Plant
# Loading Dock and Plaza
# Templated Hospital Project
# Central Utility Plant
# Original Building
# Outpatient Diag. & Treat. Center
# Boiler Enclosure
# Surgery Addition - Structurally connected to BLD-00692
# Emergency Generator
# Liquid Oxygen Enclosure
# Main/Original Building
# Emergency Addition
# Aboveground Fuel Storage Tank
# Main Hospital Building
# Engineering/Boiler Building - Structurally connected to BLD-00709
# Emergency and Critical Care Building
# Chiller/Generator Building
# Skilled Nursing Facility
# Hospital Building
# Boiler Building
# Emergency Generator Building
# Hospital Building-1967 Addition - Structurally connected to BLD-00005
# Hospital Building - 1977 Addition - Structurally connected to BLD-00005
# Lobby Addition to Hospital Building
# Building D: Service Building
# Hospital  Ambulatory Care & Inc. II
# Central Plant
# Valleycare (New) Addition
# Arcade - Phase I - Portion 1
# Arcade - Phase II - Portion 1
# Porte Cochere
# Arcade - Phase I - Portion 2
# Arcade - Phase I - Portion 3
# Arcade - Phase II - Portion 2
# Ambulance Drop Off Canopy
# Emergency Generator Set
# Cardiac Cath Lab - MPOE
# Patient Tower
# West Site Plant
# Cafeteria Addition
# Diagnostic & Treatment Building
# B/C Wing
# A/B Wing
# Loading Dock
# Western Expansion Building
# Outpatient Clinic
# Chiller Plant
# Outpatient Center 2
# Walkway
# Medical Gas Building
# Original Hospital
# South Wing Addition
# Emergency Wing Addition
# Areas No. 1 and 2 Addition
# Area No. 3 Addition
# Area No. 4 Addition
# Area No. 5 Addition
# Entrance Canopy
# Center for Joint Replacement
# Central Plant
# Center for Joint Replacement - Bridge
# Interim Loading Dock
# Underground Service Passage
# Main Building
# Canopy #1
# Canopy #2
# Canopy #3
# Pedestrian Walkway #1
# Pedestrian Walkway #2
# Pedestrian Bridge
# Emergency Room Addition
# Center for Joint Replacement - Hallway
# Pedestrian Walkway #2A
# Pedestrian Walkway #2B
# Hospital Building
# Emergency Department Entry Porte Cochere - Low
# Emergency Department Entry Porte Cochere - High
# Entry Canopy
# Original Hospital and Additions
# Radiology Addition
# Behavioral Health & Administration
# Radiology Addition
# Central Stores
# Cardiac Cath Lab
# Administration
# Surgery Addition
# Original Hospital
# O.B. First Addition - Structurally connected to BLD-00110
# O.B. Second Addition - Structurally connected to BLD-00110
# Administration Third Addition - Structurally connected to BLD-00110
# Surgery Wing
# Corridor No. 1
# South Wing - Structurally connected to BLD-00110
# Trauma
# Pharmacy
# Tower
# Cath Lab No. 1
# Radiology - Oncology  - Structurally connected to BLD-02935
# Cath Lab No. 2
# Surgery Addition
# Waiting Area/Corridor No. 2
# Magnolia Tower
# O.R. Addition
# E.R. Addition
# Rehabilitation Center
# Main Hospital Building & Additions
# East Wing Addition - Structurally connected to BLD-00090
# North Wing Addition - Structurally connected to BLD-00090
# Boiler Building
# Warehouse Addition - Structurally connected to BLD-00090
# 18 Bed Addition - Structurally connected to BLD-00090
# Surgical Addition - Structurally connected to BLD-00090
# X-Ray Addition  - Structurally connected to BLD-00090
# Entry Addition - Structurally connected to BLD-00090
# ICU Addition
# Bulk Oxygen Yard
# 1960 Original Building
# 1963 Structural Addition - Structurally connected to BLD-00134
# 1968 36 Bed Addition - Structurally connected to BLD-00134
# 1971 X-Ray Addition - Structurally connected to BLD-00134
# 1972 ICU Addition - Structurally connected to BLD-00134
# 1974 ER Addition
# 1978 Pathology Addition
# 1979 Business/Lobby Addition
# 1979 Nuclear Medicine Addition - Structurally connected to BLD-00140
# 1989 South Wing Addition
# 1997 Addition
# 1979 Kitchen/Dining Addition
# 1989 South Wing Addition - 1 story
# Orohealth Hospital New Patient Tower
# Orohealth Hospital Chiller Enclosure
# Orohealth Hospital Generator Enclosure
# North Wing
# South Wing
# ED Pedestrian Canopy
# South Wing - Link Corridor
# Steam Boilers Shed
# Main Hospital
# Bulk Medical Gas Yard
# Skilled Nursing Building
# 1 - Main Hospital
# 16 - Main Entrance Canopy
# 2 - Clinical Lab
# Cafeteria
# Lower Generator Building
# Mechanical Shed
# Original Hospital (Elevator Tower)
# C Wing
# Elevator/Stair Tower - Structurally connected to BLD-02472
# C Wing-East Wing-North West Element - Structurally connected to BLD-02476
# D Wing
# D Wing-North Wing-Infill - Structurally connected to BLD-02473
# C Wing Addition
# Linear Accelerator
# B Wing / Surgery Equipment Room
# Surgery Equipment Room - Structurally connected to BLD-02480
# Cancer Center
# Emergency Room
# Canopy - Structurally connected to BLD-02483
# A Wing
# Linear Accelerator
# Central Plant
# Boiler Plant
# Canopy 1
# Ambulance Canopy
# Canopy 2
# Canopy 3
# E Tower
# E-1
# HVAC Tunnel
# LOX Yard
# Original Hospital (Tower & Low Rise)
# Phase 2 Tower
# Phase 2 Cafeteria / Cardiology
# Phase 2 ER / Radiology
# Phase 3 West Wing
# MRI Addition - Structurally connected to BLD-00478
# Central Plant
# Phase 4 Tower
# Phase 3  West Wing - East Portion
# Hospital Building
# Central Utility Plant
# Hospital Building
# Central Service Building
# Central Plant
# North Addition (Hospital Tower)
# Phase 1 Hospital - Utility Expansion
# Phase II Hospital
# Generator Plant
# Waste, Gas Farm Enclosure
# Phase II Link Corridor
# Drop Off Canopy
# Main Hospital
# ED Expansion
# OR Expansion
# New Pharmacy
# Infrastructure Yard
# Rehabilitation Hospital
# Original Hospital
# ER / Lab Expansion
# Nursing Tower
# Ambulatory Services
# Mechanical Building - Structurally connected to BLD-02461
# OR Storage Expansion
# Entrance Canopy
# Womens Center
# Nursing Tower - Central Plant
# Nursing Tower - Dining Addition
# Nursing Tower - Admin Building
# Nursing Tower - Lobby Building
# Hospital Building
# Special Care Unit
# Original and Nursing Wing Addition
# Two Story Addition
# Mechanical Plant and Addition
# MRI Addition
# New Central Utility Plant
# Utility Tunnel
# Original Building (Bldg I)
# 1971 Addition No. 1 (Bldg II)
# 1971 Addition No. 2 (Bldg III) - Structurally connected to BLD-00489
# 1974 Addition (Bldg IV)
# 1981 Addition No. 1 (Bldg V)
# 1981 Addition No. 2 (Bldg VI)
# 1988 Addition (Bldg VII)
# 1991 Addition (Bldg VIII) - Structurally connected to BLD-00494
# 1964 Addition (Bldg IX) - Structurally connected to BLD-00489
# 2012 Addition
# 2012 Addition - Connecting Corridor
# 2012 Addition - Bridge
# 2012 Addition - South Canopy
# 2012 Addition - Center Canopy
# 2012 Addition - North Canopy
# Equipment Yard
# Ambulance Canopy
# Main Hospital Building
# Mechanical Building
# Rec. Room & Office Addition
# Lab & Storage Addition
# Canopy Addition
# Birthing Center
# LDR Addition
# ER / Radiology / Clinic Addition
# Generator Shed
# Lobby Remodel & Addition
# Corridor Addition
# Mechanical & Electrical Building Addition
# Main Entrance Canopy Addition
# ER Canopy Addition
# Medical / Surgical / Birthing
# Maintenance Building
# Nursing Wing
# Emergency / Laboratory
# Multi-Use Facility
# Warehouse
# Nursing Unit
# Diagnosis and Treatment
# Administration and Support
# Central Plant
# Central Plant Expansion
# Bed Tower
# Diagnostic & Treatment Expansion
# Support Expansion 1
# Support Expansion 2
# Canopy 1
# North Bed Tower
# Support Expansion 3A
# Support Expansion 3B
# Diagnostic & Treatment Expansion 3A
# Diagnostic & Treatment Expansion 3B
# Utility Racks
# Bottle Storage
# Front Entry
# Entry Canopy-North
# Entry Canopy-South
# Emergency Entry Canopy
# Main Hospital Building
# SNF Building
# West Wing / East Wing
# Radiology Addition
# Aa - East Wing
# Ab - East Wing
# Ac - East Wing
# Ad - East Wing
# Ae - East Wing
# Angiography Addition
# Trauma & Critical Care Center
# New Central Plant
# Utility Tunnel
# D/P Skilled Nursing Facility
# MRI Building
# Data Center Building
# Trauma Center Corridor
# Trauma Center Utility Tunnel
# Main Hospital
# Central Plant
# Wing A
# Recovery Center
# Expansion
# New Tower
# Equipment Yard
# Sequoia Mall
# Hospital Tower North
# Hospital Tower South
# Ancillary/Yosemite Building
# Ancillary Building Addition
# Utility/Grapevine Building
# Cooling Tower Yard
# Medical Gas Storage
# Medical Waste Enclosure
# Med Gas Cylinder Canopy
# Emergency Department Expansion
# Entrance Canopy
# Utility Shaft
# Fuel Pump House
# Connecting Corridor
# Utility Tunnel
# Carpenter Shop
# Medical Waste Enclosure
# Main Building
# West Addition
# Cogeneration Building
# Chapel
# Northwest Addition
# East Addition
# Central Plant
# Cath Recovery Building
# North Addition
# Canopy and Bridges
# UPS Flywheel Enclosure
# 21 KV Switchgear Building
# Fire Pump / Chiller Building
# North Addition Auditorium
# North Addition Canopy #1
# North Addition Canopy #2
# Hospital Building
# Main Hospital Building
# Garage Building
# 600 Wing (Accounting) Addition
# Nurses Locker Addition
# Main Building - ICU Addition
# Main Building - Dietary / Purchasing
# Main Building - 700 Wing South
# Main Building - 700 Wing North
# Main Building - 800 Wing
# Main Building - Medical / Surgery
# Shop & Maint. Building
# Main Building and Additions
# ER Addition
# Clinic Building and Additions
# Main Hospital
# Central Plant
# Administration/Urgent Care
# Short Stay Surgery
# Obstetrics Addition
# AHU Platform
# Conference Room Addition
# Original Building
# O.B. Addition
# Generator Building
# East Wing Expansion
# E. Wing Canopy
# Surgery Department - Structurally connected to BLD-00529
# Rehab. Addition
# Original Hospital and Central Plant
# Linear Accelerator (Phase II)
# Phase III Addition Building
# Emergency Entrance Vestibule
# Radiation Oncology Addition
# Heart Center
# East Wing
# Emergency Entrance Vestibule Addition
# Emergency Generator #1 CMU Building
# Emergency Generator #2 Enclosure Shed
# Northeast Building Entry Link
# Fire Pump House
# Northeast Building
# Northeast Building Ambulance Canopy
# Northeast Building Entry Canopy
# Hospital
# Entry Canopy
# ED Canopy
# Original Hospital Building
# 1950 Addition Building
# 1955 Addition Building
# Center Building - 1957 Addition
# West Side Building - 1957 Addition
# Stair #1
# Nursery
# Stair #2
# Stair #3
# Radiology Wing
# Lobby
# South Wing
# L/D Bldg
# Central Wing
# West Addition - Structurally connected to BLD-00754
# Central Plant
# North Wing
# ICU Addition - Structurally connected to BLD-00757
# Admin Bldg
# OB Building
# Radiology Building
# Rad Annex
# Lab Building
# Annex
# East Wing - South
# New Wing
# New Central Plant
# Admin Bldg Addition
# East Wing - North
# Electrical Room
# Generator Yard
# Ancillary Services Building
# Cooling Tower Yard
# Data Center Building
# Emergency Department Expansion
# Entrance Lobby
# Entrance Canopy
# Driveway Canopy
# Ambulance Canopy
# Utility Canopy
# North ASB Utility Canopy
# South ASB Utility Canopy
# ASB Covered Link
# Central Plant Shed
# Hazardous Waste Storage
# Pharmacy Expansion
# Original Hospital
# Original Power Plant
# Administration Wing
# ICU Addition
# Outpatient Addition
# Women's Center
# ER
# New Power Plant
# Dietary
# Link between 05B and 01A
# Link between 05B and 05C
# Surgery Addition
# ED Expansion
# Emergency Generator Yard
# Main Hosp Bldg/Existing Central Plant

# %% [markdown]
# Brief description of specific data parsed.
# The parsed data contains buildings names of hospitals
